# %%
import pandas as pd

# %% [markdown]
# ### CATEGORIZE EXPENSES

# %%
categories = [  
                'A: Groceries',
                'A: Medical and Dental',
                'A: Gas n Car Maintenance',
                'B: Clothes',
                'B: Beauty n Health',
                'B: House and Garden',
                'B: Pharmacy',
                'B: Professional Fees', 
                'B: Software n Accessories',
                'B: Amazon',
                'C: Subscription',
                'C: Pets', 
                'C: Fast Food',
                'C: College n Art Supplies',
                'C: Art Supplies', 
                'D: Kindle n Books',
                'D: Department',
                'D: Dining Out',
                'D: Political Donations', 
                'D: Kids Toys', 
                'E: Entertainment n Gifts', 
                'Q: Why DOORDASH ?',
                'U: Uncategorized', 
                'V: Visiting Grandma Ela',
                'V: Vacation SC',
                'V: Visiting Wanda',
                'V: Visiting Eva',
                'X: Air Travel', 
                'X: Fees',
                'Z: Accounted Elsewhere', 
                'Z: PAYMENT'
                ]

all_categories = pd.DataFrame({'Category': categories})
print(all_categories)

def get_category(expense_category):
    if expense_category not in categories:
        print(f"ERROR ! Category '{expense_category}' does not exist in the predefined categories.")
    return expense_category
# Out:
#                      Category
# 0                A: Groceries
# 1       A: Medical and Dental
# 2    A: Gas n Car Maintenance
# 3                  B: Clothes
# 4          B: Beauty n Health
# 5         B: House and Garden
# 6                 B: Pharmacy
# 7             C: Subscription
# 8                     C: Pets
# 9                C: Fast Food
# 10  C: College n Art Supplies
# 11            C: Art Supplies
# 12       B: Professional Fees
# 13  B: Software n Accessories
# 14                  B: Amazon
# 15              D: Department
# 16              D: Dining Out
# 17     D: Political Donations
# 18               D: Kids Toys
# 19   E: Entertainment n Gifts
# 20          Q: Why DOORDASH ?
# 21           U: Uncategorized
# 22                    X: Fees
# 23    V: Visiting Grandma Ela
# 24             V: Vacation SC
# 25          V: Visiting Wanda
# 26            V: Visiting Eva
# 27              X: Air Travel
# 28     Z: Accounted Elsewhere
# 29                 Z: PAYMENT

# %%
import re # re.search etc. regular expressions

def categorize(description):
    # FEES - FOREIGN contains REI and causes a conflict
    if 'TRANSACTION FEE' in description.upper():
        return get_category('X: Fees')
    # POLAND 
    elif    re.search(r' POL$', description.upper()) \
            or re.search(r' IL$', description.upper()) \
            or 'PLUSKI' in description.upper() \
            or 'OLSZTYN' in description.upper() :
        return  get_category('V: Visiting Grandma Ela')
    # VACATION
    elif    'FOLLY' in description.upper()  \
            or re.search(r' SC$', description.upper()) \
            or re.search(r' NC$', description.upper())  or re.search(r' WV$', description.upper()) \
            or 'VIATORTRIPADVISOR' in description.upper() \
            or 'VACASA' in description.upper()      or 'VRBO' in description.upper() :
        return  get_category('V: Vacation SC')
    # VISITING WANDA
    elif    re.search(r' VA$', description.upper()) \
            or re.search(r' GA$', description.upper()) \
            or  re.search(r' MD$', description.upper()) :
        return  get_category('V: Visiting Wanda')
    # VISITING EVA
    elif    re.search(r' PA$', description.upper())           or ' TURNPIKE ' in description.upper() \
            or 'PITTSBURGH' in description.upper() :
        return  get_category('V: Visiting Eva')
    # GROCERY
    elif    'GROCERY' in description.upper()        or 'HEINEN' in description.upper() \
            or 'DAVE' in description.upper()        or 'WHOLE' in description.upper() \
            or 'SODA' in description.upper()        or 'TRADE' in description.upper() :
        return  get_category('A: Groceries')
    # DINING OUT
    elif    'TAVERN' in description.upper()         or 'TOMMYS' in description.upper() \
            or 'CAFE' in description.upper() \
            or 'WASABI' in description.upper()      or 'PACIFIC' in description.upper() \
            or 'ANATOLIA' in description.upper()    or 'BATUQUI' in description.upper() \
            or 'PHO' in description.upper()         or 'LAKE HOUSE' in description.upper() \
            or 'DEWEY' in description.upper()       or 'BANANA' in description.upper() \
            or 'BANGKOK' in description.upper()     or 'HIBACHI' in description.upper() \
            or 'LOTUS' in description.upper()       or 'SUBSHOPPE' in description.upper() \
            or 'NATURES OASIS' in description.upper()    or 'BRASSICA' in description.upper() \
            or 'RESTAUR' in description.upper()     or 'BUFFALO' in description.upper() :
        return  get_category('D: Dining Out')
    # NATIONAL GROCERY n FOOD
    elif    'KRAKOW' in description.upper()        or 'NIPA HUT' in description.upper() :
        return  get_category('C: World Food')
    # DOORDASH FOOD
    elif    'DOORDASH' in description.upper() :
        return  get_category('Q: Why DOORDASH ?')
    # FAST FOOD
    elif    'LEFTY' in description.upper()          or 'SHAKE SHACK' in description.upper() \
            or 'WENDY' in description.upper()       or 'BUDDA' in description.upper() \
            or 'CILANTRO' in description.upper()    or 'PANERA' in description.upper() \
            or 'CHIPOTLE' in description.upper()    or 'BIBIBOP' in description.upper() \
            or 'ROGERS' in description.upper():
        return  get_category('C: Fast Food')
    # BEAUTY n HEALTH
    elif    'LADIES' in description.upper()             or 'BATH' in description.upper() \
            or 'SALLY BEAUTY' in description.upper()    or 'AVEDA' in description.upper() \
            or 'LUSH BEACHWOOD' in description.upper() \
            or 'AIKIKAI' in description.upper()         or 'AIKIDO' in description.upper() \
            or 'ATMA' in description.upper()            or 'PADDLE' in description.upper():
        return  get_category('B: Beauty n Health')
    # MEDICAL n DENTAL
    # WESTERN RESERVE PERIO - Tomek's paradontist  
    elif    'PEDIATRICS' in description.upper()     or 'CLEVELAND CLINIC' in description.upper() \
            or 'METROHEALTH' in description.upper() \
            or 'WESTERN RESERVE PERIO' in description.upper():
        return  get_category('A: Medical and Dental')
    # PHARMACY 
    elif    'CVS' in description.upper()            or 'WALGREENS' in description.upper():
        return  get_category('B: Pharmacy')
    # HOUSE n GARDEN  
    elif    'HOME DEPOT' in description.upper()     or 'BREMEC' in description.upper() \
            or 'LANDSCAPE' in description.upper()   or 'STUMP' in description.upper() \
            or 'NATURE CENTER' in description.upper() or 'REFURNISHING' in description.upper() :
        return  get_category('B: House and Garden')
    # SUBSCRIPTIONS
    elif    'SPOTIFY' in  description.upper()       or 'APPLE' in description.upper() \
            or 'NETFLIX' in description.upper()     or 'AUDIBLE' in description.upper() \
            or 'PEACOCK' in description.upper()     or 'WALL' in description.upper() \
            or 'BITDEFENDER' in description.upper() or 'MICROSOFT' in description.upper() \
            or 'HULU' in description.upper()        or 'NYTIMES' in description.upper():
        return  get_category('C: Subscription')
    # AMAZON
    elif    'AMAZON' in description.upper()         or 'AMZN' in description.upper():
        return  get_category('B: Amazon')
    # KINDLE n BOOKS
    elif    'KINDLE' in description.upper()         or 'AUDIOTEKA' in description.upper() \
        or 'LOGANBERRY' in description.upper()      or 'EMPIK' in description.upper() :
        return  get_category('D: Kindle n Books')
    # SOFTWARE n ACCESSORIES
    elif    'CLIP STUDIO' in description.upper()    or 'ALIEXPRESS' in description.upper():
        return  get_category('B: Software n Accessories')
    # DEPARTMENT STORES
    elif    'TARGET' in description.upper()         or 'MACY' in description.upper():
        return  get_category('D: Department')
    # CLOTHES
    elif    'REI' in description.upper()                or 'NORDSTROM' in description.upper() \
            or 'DICK' in description.upper()            or 'DSW' in description.upper() \
            or 'AVALON' in description.upper()          or 'MARSHALLS' in description.upper() \
            or 'AMERICAN EAGLE' in description.upper()  or 'FOOTWEAR' in description.upper():
        return  get_category('B: Clothes')
    # PETS
    elif    'PET' in description.upper()            or 'CHEWY' in description.upper() \
            or 'HOLLYWOOD FEED' in description.upper() or 'JACKSON GALAXY' in description.upper() \
            or 'VETERINARY' in description.upper()  or 'PET' in description.upper():
        return  get_category('C: Pets')
    # ENTERTAINMENT n GIFTS
            # MOVIES THEATER COMPUTER GAMES BIRTHDAY CAKES BDAY DINNERS ETC
            # NOTE: CLEVELAND INSTITUTE OF CLEVELAND ==== CIA CINEMATEQUE
            # MUSEUM ===== includes THE CHILDRENS MUSEUM O CLEVELAND OH 
            # GREATER CLEVELAND AQUA ==== CLEVELAND AQUARIUM
            # MANGO MANGO DESSE CLEVELAND ===== mango mango dessert Sof's birthday with Felix
            # DIAMONDS FLOWERS ========= flower shop Coventry
    elif    'VUDU' in description.upper()               or 'FANDANGO' in description.upper() \
            or 'DOBAMA' in description.upper() \
            or 'CMA' in description.upper()             or 'MUSEUM' in description.upper() \
            or 'THEAT' in description.upper()           or 'CLEVELAND PUBLIC' in description.upper() \
            or 'CLEVELAND INSTITUTE OF CLEVELAND' in description.upper() \
            or 'GREATER CLEVELAND AQUA' in description.upper() \
            or 'BANDCAMP' in description.upper()        or 'MOVIE' in description.upper() \
            or 'PRIME VIDEO' in description.upper()     or 'MITCHELL' in description.upper() \
            or 'BORDERLIGHT' in description.upper()     or 'CINEMA' in description.upper() \
            or 'STEAMGAMES' in description.upper()      or 'STEAM PURCHASE' in description.upper() \
            or 'FIDDLEHEAD' in description.upper()      or 'PASSPORT' in description.upper() \
            or 'SWEET FIX' in description.upper()       or 'STONE OVEN' in description.upper() \
            or 'MANGO MANGO DESSE' in description.upper() or 'DIAMONDS FLOWERS' in description.upper() \
            or 'ON THE RISE' in description.upper()     or 'RISING STAR COFFEE' in description.upper() \
            or 'MICHAELS' in description.upper()        or 'BUNDT' in description.upper() \
            or 'ALL CITY CANDY' in description.upper()  or 'UPTOWN MART' in description.upper() \
            or 'ELLIE-MAYS' in description.upper()      or '6 FLAVORS INDIAN' in description.upper() \
            or 'LUXE KITCHEN' in description.upper() :
        return  get_category('E: Entertainment n Gifts')
    # GAS n CAR MAINTENANCE
    # NOTE: SHAKER QUALITY AUTO CLEVELAND OH
    elif    'SUNOCO' in description.upper()         or 'BP' in description.upper() \
            or 'REPAIR' in description.upper()      or 'AUTO' in description.upper() \
            or 'MARATHON' in description.upper()    or 'SHELL' in description.upper() \
            or 'CIRCLE K' in description.upper()    or 'SHEETZ' in description.upper() \
            or 'GAS' in description.upper() \
            or 'BODY' in description.upper()        or 'QUALITY AUTO' in description.upper()  \
            or 'BUREAU MOTOR VE'  in description.upper() :
        return  get_category('A: Gas n Car Maintenance')
    # COLEGE 
    elif    'CIA' in description.upper()            or 'BURREN' in description.upper() \
            or 'UTRECHT' in description.upper()     or 'COLLEGE' in description.upper():
        return  get_category('C: College n Art Supplies')
    # ART SUPPLIES
    elif    'UTRECHT' in description.upper()            or ' ART ' in description.upper() :
        return  get_category('C: Art Supplies')
    # AIR TRAVEL
    elif    'LOT ' in description.upper()           or 'AMERICAN' in description.upper() \
            or 'EXPEDIA' in description.upper():
        return  get_category('X: Air Travel')
    # TOYS
    elif    'PLAYMATTERS' in description.upper()    or 'DISNEYSTORE' in description.upper():
        return  get_category('D: Kids Toys')
    # POLITICAL DONATIONS
    elif    'ACTBLUE' in description.upper():
        return  get_category('D: Political Donations')
    # PROFESSIONAL CERT n FEES
    elif    'LICENSURE' in description.upper()      or 'LICENSE' in description.upper():
        return  get_category('B: Professional Fees')
    # PAYMENT
    elif    'PAYMENT' in description.upper():
        return  get_category('Z: PAYMENT')
    # ACCOUNTED 4 ELSEWHERE
    elif    'DELTA DENTAL' in description.upper():
        return  get_category('Z: Accounted Elsewhere')
    # OTHER
    else:
        return  get_category('U: Uncategorized')

# %%
def categorize_all(input_period):
    
    input_datafile = input_period + '-A&T-CCard.xlsx'
    output_datafile_categorized = input_period + '-A&T-CCard-CATEGORIZED.csv'
    output_datafile_categorized_sorted = input_period + '-A&T-CCard-SORTED-BY-CATEGORY.csv'
    output_datafile_summary = input_period + '-A&T-CCard-SUMMARY.csv'

    # Load the data
    data = pd.read_excel(input_datafile)
    data.columns = ['Date', 'Amount', 'Description', 'Ref,#']

    # Categorize by description and add Category column
    data['Category'] = data['Description'].apply(categorize)
    # Save the updated DataFrame to a new CSV file
    data.to_csv(output_datafile_categorized, index=False)

    # Group transactions by category (e.g., food, clothing, entertainment) and calculate total amounts for each category
    # categories = ['Groceries', 'Subscription', 'Dining Out']
    sorted_by_category = data.sort_values(by='Category', ascending=True)
    # save sorted data to a file
    sorted_by_category.to_csv(output_datafile_categorized_sorted)

    # Summarize amounts in grouped categories
    grouped_summary = data.groupby('Category')['Amount'].sum().reset_index()
    
    #cat_num = data["Category"].nunique()
    cat_num = all_categories["Category"].nunique()
    merged_summary = all_categories.merge(grouped_summary, on='Category', how='left')
    merged_summary = merged_summary.fillna(0)
    print(merged_summary)

    # sorted_summary = grouped_summary.sort_values(by='Amount', ascending=False).head(cat_num)
    sorted_summary = merged_summary.sort_values(by='Category', ascending=True).head(cat_num)
    sorted_summary.to_csv(output_datafile_summary, index=False)

# %%
categorize_all('2024-01')
# Out:
#                      Category   Amount
# 0                A: Groceries -1220.32
# 1       A: Medical and Dental   -50.00
# 2    A: Gas n Car Maintenance   -95.78
# 3                  B: Clothes     0.00
# 4          B: Beauty n Health  -282.36
# 5         B: House and Garden   -78.94
# 6                 B: Pharmacy  -136.39
# 7             C: Subscription  -163.53
# 8                     C: Pets -2073.86
# 9                C: Fast Food   -30.08
# 10  C: College n Art Supplies    -4.46
# 11            C: Art Supplies     0.00
# 12       B: Professional Fees  -191.96
# 13  B: Software n Accessories     0.00
# 14                  B: Amazon  -379.54
# 15              D: Department   -72.89
# 16              D: Dining Out  -419.68
# 17     D: Political Donations     0.00
# 18               D: Kids Toys     0.00
# 19   E: Entertainment n Gifts  -298.66
# 20          Q: Why DOORDASH ?     0.00
# 21           U: Uncategorized    -7.78
# 22                    X: Fees     0.00
# ...

# %%
categorize_all('2024-02')
categorize_all('2024-03')
categorize_all('2024-04')
categorize_all('2024-05')
categorize_all('2024-06')
categorize_all('2024-07')
categorize_all('2024-08')
categorize_all('2024-09')
# Out:
# ERROR ! Category 'D: Kindle n Books' does not exist in the predefined categories.
# ERROR ! Category 'D: Kindle n Books' does not exist in the predefined categories.
#                      Category   Amount
# 0                A: Groceries -1300.73
# 1       A: Medical and Dental     0.00
# 2    A: Gas n Car Maintenance   -61.12
# 3                  B: Clothes   -19.98
# 4          B: Beauty n Health  -132.53
# 5         B: House and Garden  -307.74
# 6                 B: Pharmacy   -97.24
# 7             C: Subscription  -161.48
# 8                     C: Pets  -744.03
# 9                C: Fast Food     0.00
# 10  C: College n Art Supplies     0.00
# 11            C: Art Supplies     0.00
# 12       B: Professional Fees  -103.50
# 13  B: Software n Accessories    -9.99
# 14                  B: Amazon  -423.90
# 15              D: Department     0.00
# 16              D: Dining Out  -376.47
# 17     D: Political Donations   -25.00
# 18               D: Kids Toys     0.00
# ...

# %%
# Select period and define filenames
input_period = '2024-09'
input_datafile = input_period + '-A&T-CCard.xlsx'
output_datafile_categorized = input_period + '-A&T-CCard-CATEGORIZED.csv'
output_datafile_categorized_sorted = input_period + '-A&T-CCard-SORTED-BY-CATEGORY.csv'
output_datafile_summary = input_period + '-A&T-CCard-SUMMARY.csv'
print(input_datafile)
print(output_datafile_categorized)
print(output_datafile_categorized_sorted)
print(output_datafile_summary)
# Out:
# 2024-09-A&T-CCard.xlsx
# 2024-09-A&T-CCard-CATEGORIZED.csv
# 2024-09-A&T-CCard-SORTED-BY-CATEGORY.csv
# 2024-09-A&T-CCard-SUMMARY.csv

# %%
# Load the data
data = pd.read_excel(input_datafile)
data.columns = ['Date', 'Amount', 'Description', 'Ref,#']

print(data.head())
# Out:
#         Date  Amount                             Description  Ref,#
# 0 2024-09-29  -33.15     CVS/PHARMACY #03634 CLEVELAND HTSOH   6089
# 1 2024-09-28 -247.09      WHOLEFDS CTR 10199 UNIVERSITY HTOH   6089
# 2 2024-09-28  -72.94         PETSMART # 2313 UNIVERSITY HEOH   6089
# 3 2024-09-29  -55.59  MED*SENDERS PEDIATRICS 216-291-9210 OH   6089
# 4 2024-09-27  -18.69  TST*YOURS TRULY RESTAU Chagrin FallsOH   6089

# %%
data['Category'] = data['Description'].apply(categorize)
print(data.head())
# Out:
#         Date  Amount                             Description  Ref,#  \
# 0 2024-09-29  -33.15     CVS/PHARMACY #03634 CLEVELAND HTSOH   6089
# 1 2024-09-28 -247.09      WHOLEFDS CTR 10199 UNIVERSITY HTOH   6089
# 2 2024-09-28  -72.94         PETSMART # 2313 UNIVERSITY HEOH   6089
# 3 2024-09-29  -55.59  MED*SENDERS PEDIATRICS 216-291-9210 OH   6089
# 4 2024-09-27  -18.69  TST*YOURS TRULY RESTAU Chagrin FallsOH   6089
#
#              Category
# 0            Pharmacy
# 1           Groceries
# 2                Pets
# 3  Medical and Dental
# 4       Uncategorized

# %%
# Save the updated DataFrame to a new CSV file
data.to_csv(output_datafile_categorized, index=False)
print(data)
# Out:
#          Date  Amount                             Description  Ref,#  \
# 0  2024-09-29  -33.15     CVS/PHARMACY #03634 CLEVELAND HTSOH   6089
# 1  2024-09-28 -247.09      WHOLEFDS CTR 10199 UNIVERSITY HTOH   6089
# 2  2024-09-28  -72.94         PETSMART # 2313 UNIVERSITY HEOH   6089
# 3  2024-09-29  -55.59  MED*SENDERS PEDIATRICS 216-291-9210 OH   6089
# 4  2024-09-27  -18.69  TST*YOURS TRULY RESTAU Chagrin FallsOH   6089
# ..        ...     ...                                     ...    ...
# 72 2024-09-04   -2.49              ZABKA Z8885 K.2 OLSZTYN 28   4123
# 73 2024-09-01  -55.93      WHOLEFDS CTR 10199 UNIVERSITY HTOH   6089
# 74 2024-09-02  -12.95               AMAZON DIGITAL SEATTLE WA   4123
# 75 2024-09-02  -24.83              NETFLIX.COM NETFLIX.COM CA   4123
# 76 2024-09-01  -19.43     HULU 877-8244858 CA SANTA MONICA CA   4123
#
#               Category
# 0             Pharmacy
# 1            Groceries
# 2                 Pets
# 3   Medical and Dental
# ...

# %%
unique_categories = data["Category"].unique()
print(unique_categories)
print(unique_categories.shape)
cat_num = unique_categories.shape[0]
print(cat_num)
# Out:
# ['Pharmacy' 'Groceries' 'Pets' 'Medical and Dental' 'Uncategorized'
#  'Entertainment n Gifts' 'Amazon' 'Dining Out' 'Gas n Car Maintenance'
#  'Political Donations' 'Beauty n Health' 'Clothes' 'Fees' 'Kindle n Books'
#  'Saving Grandma Ela' 'Subscription' 'Accounted Elsewhere']
# (17,)
# 17

# %%
# Group transactions by category (e.g., food, clothing, entertainment) and calculate total amounts for each category
# categories = ['Groceries', 'Subscription', 'Dining Out']
sorted_by_category = data.sort_values(by='Category', ascending=True)
sorted_by_category.to_csv(output_datafile_categorized_sorted)
print(sorted_by_category)
# Out:
#          Date  Amount                             Description  Ref,#  \
# 69 2024-09-05 -162.36    DELTA DENTAL OF OHIO INDIANAPOLIS IN   4123
# 25 2024-09-19  -10.27  AMAZON MKTPL*V36FI0823 Amzn.com/billWA   4123
# 27 2024-09-17  -10.79  AMAZON MKTPL*FT8WR7JC3 Amzn.com/billWA   4123
# 33 2024-09-14   -5.39  AMAZON MKTPL*LY5QY57X3 Amzn.com/billWA   4123
# 36 2024-09-14  -57.22    Amazon.com*ZC0YB7ED3 Amzn.com/billWA   4123
# ..        ...     ...                                     ...    ...
# 76 2024-09-01  -19.43     HULU 877-8244858 CA SANTA MONICA CA   4123
# 31 2024-09-14  -85.85      USPS PO 3816550181 CLEVELAND HEIOH   4123
# 11 2024-09-26   -8.64                 D J*WSJ 800-568-7625 NJ   4123
# 4  2024-09-27  -18.69  TST*YOURS TRULY RESTAU Chagrin FallsOH   6089
# 43 2024-09-12   -5.00  2689PEPSIVEN9147678600 ELK GROVE VILIL   4123
#
#                Category
# 69  Accounted Elsewhere
# 25               Amazon
# 27               Amazon
# 33               Amazon
# ...

# %%
# Summarize amounts in grouped categories
grouped_summary = data.groupby('Category')['Amount'].sum().reset_index()
sorted_summary = grouped_summary.sort_values(by='Amount', ascending=False).head(cat_num)
sorted_summary.to_csv(output_datafile_summary, index=False)
print(sorted_summary)
# Out:
#                  Category   Amount
# 6                    Fees    -8.98
# 9          Kindle n Books    -9.29
# 13    Political Donations   -26.00
# 12               Pharmacy   -46.64
# 10     Medical and Dental   -55.59
# 15           Subscription   -99.83
# 7   Gas n Car Maintenance  -104.82
# 16          Uncategorized  -118.18
# 5   Entertainment n Gifts  -132.15
# 3                 Clothes  -158.74
# 0     Accounted Elsewhere  -162.36
# 11                   Pets  -218.50
# 1                  Amazon  -244.64
# 2         Beauty n Health  -327.24
# 14     Saving Grandma Ela  -371.20
# 4              Dining Out  -496.82
# 8               Groceries -1111.63
